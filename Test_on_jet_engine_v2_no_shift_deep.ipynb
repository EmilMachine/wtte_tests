# %% [markdown]
# # TRY WTTE on enigine failure
#
# Based on data from NASA
# - https://c3.nasa.gov/dashlink/resources/139/
#
# Direct data link
# - http://ti.arc.nasa.gov/c/6/
#
# Inspired by
# - https://ragulpr.github.io/2016/12/22/WTTE-RNN-Hackless-churn-modeling/
#
# Data pipeline guides
# - https://github.com/ragulpr/wtte-rnn-examples/blob/master/examples/hello-world-datapipeline.ipynb
# - https://github.com/ragulpr/wtte-rnn-examples/blob/master/examples/data-pipeline-template.ipynb

# %%
### INSTALL PACKAGES

#!pip2 install wtte

# %%
# setup matplotlib
import matplotlib
matplotlib.use('TkAgg')

# %%
# %matplotlib inline
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
from six.moves import xrange

import pandas as pd
import numpy as np
from wtte.data_generators import generate_random_df
import wtte.transforms as tr
import matplotlib.pyplot as plt

import wtte.weibull
from wtte.plots.misc import timeline_plot
from wtte.plots.misc import timeline_aggregate_plot
pd.options.display.max_rows = 10

# %%
### LOAD DATA

data1 = pd.read_csv("./CMAPSSData/train_FD004.txt",sep=" ",header=None)
col_id =0
col_time = 1
dataraw = data1.rename(index=str, columns={col_id: "id", col_time: "time"})

## Last Entry for each id (max_time) (event =1)
maxtime = dataraw[["time","id"]].groupby(["id"]).agg("max")
maxtime["event"] = 1
maxtime.reset_index(level=0, inplace=True)

## JOIN BACK IN AND FILL NANS (event will be 1 for last entry 0 otherwise)
new_df = pd.merge(dataraw, maxtime, how='left', on=['id', 'time'])
dataset = new_df.fillna(0)

dataset.head(3)
# Out:
#    id  time        2       3      4       5       6        7        8     9  \
# 0   1     1  42.0049  0.8400  100.0  445.00  549.68  1343.43  1112.93  3.91
# 1   1     2  20.0020  0.7002  100.0  491.19  606.07  1477.61  1237.50  9.35
# 2   1     3  42.0038  0.8409  100.0  445.00  548.95  1343.12  1117.05  3.91
#
#    ...        19    20   21    22     23     24       25   26   27  event
# 0  ...    9.3335  0.02  330  2212  100.0  10.62   6.3670  0.0  0.0    0.0
# 1  ...    9.1913  0.02  361  2324  100.0  24.37  14.6552  0.0  0.0    0.0
# 2  ...    9.4007  0.02  329  2212  100.0  10.48   6.4213  0.0  0.0    0.0
#
# [3 rows x 29 columns]

# %%
### DO PLOTS OF EVENT END TIME AND DATA POINTS
plt.scatter(dataset["time"],dataset["id"],0.1,label='event')
plt.xlabel('time')
plt.ylabel('user')
plt.legend()

# %%
### DO SIMPLE SPLIT BASED ON ID (COULD BE RANDOMIZED)
idmax = dataset["id"].max()
val_ratio = .2

dataset_train = dataset[dataset["id"]>=idmax*val_ratio]
dataset_test = dataset[dataset["id"]<idmax*val_ratio]

### GRAB data colnames
c =dataset.columns
data_col_names = [i for i in c if i not in ["id,time,event"]]

# train set
events_train  = tr.df_to_padded(df=dataset_train,column_names=['event'],t_col="time")
x_train       = tr.df_to_padded(df=dataset_train,column_names=(['event']+data_col_names),t_col="time")

# set set
events_test  =  tr.df_to_padded(df=dataset_test,column_names=['event'],t_col="time")
x_test       =  tr.df_to_padded(df=dataset_test,column_names=(['event']+data_col_names),t_col="time")


print("%i ids for training\n %i ids for testing" % (len(x_train),len(x_test)))
print(x_test.shape)
print(events_test.shape)
# Out:
# 200 ids for training
#  49 ids for testing
# (49, 447, 30)
# (49, 447, 1)

# %%
timeline_plot(np.squeeze(events_train),'training events',cmap='Accent_r');

# %%
def prep_tensors(x,events,disalign=False):
    # 0. calculate time to event and censoring indicators.
    y  = np.copy(np.concatenate([events,events],-1))
    y[:,:,0] = tr.padded_events_to_tte(np.squeeze(events),discrete_time=True)
    y[:,:,1] = tr.padded_events_to_not_censored(np.squeeze(events),discrete_time=True)

    if(disalign):
        # 1. Disalign features and targets otherwise truth is leaked.
        # 2. drop first timestep (that we now dont have features for)
        # 3. nan-mask the last timestep of features. (that we now don't have targets for)
        events = events[:,1:,]
        y  = y[:,1:]
        x  = np.roll(x, shift=1, axis=1)[:,1:,]
        x  = x + 0*events
    
    return x,y,events

x_test,y_test,events_test   = prep_tensors(x_test,events_test,disalign=True)
x_train,y_train,events_train = prep_tensors(x_train,events_train,disalign=True)

timeline_plot(1-y_train[:,:,0],'Uncensored',cmap='Greys');
plt.show()
timeline_plot(1-y_train[:,:,1],'Censored',cmap='Greys');
plt.show()

print('mean uncensored (train): ',np.nanmean(y_train[:,:,1]))
print('mean uncensored (test) : ',np.nanmean(y_test[:,:,1]))
print('mean tte (test):         ',np.nanmean(y_test[:,:,0]))
print('max  tte (test):         ',np.nanmax(y_test[:,:,0]))
# Out:
# mean uncensored (train):  1.0
# mean uncensored (test) :  1.0
# mean tte (test):          135.629635563
# max  tte (test):          445.0

# %%
print(type(x_test))
print(type(y_test))
print(type(events_test))

print(x_test.shape)
print(y_test.shape)
print(events_test.shape)
# Out:
# <type 'numpy.ndarray'>
# <type 'numpy.ndarray'>
# <type 'numpy.ndarray'>
# (49, 446, 30)
# (49, 446, 2)
# (49, 446, 1)

# %%
def nanmask_to_keras_mask(x,y,mask_value,tte_mask):
    """nanmask to keras mask.
        :param float mask_value: Use some improbable telltale value 
                                (but not nan-causing)
        :param float tte_mask: something that wont NaN the loss-function
    """
    # Use some improbable telltale value (but not nan-causing)
    x[:,:,:][np.isnan(x)] = mask_value
    y[:,:,0][np.isnan(y[:,:,0])] = tte_mask
    y[:,:,1][np.isnan(y[:,:,1])] = 0.95
    sample_weights = (x[:,:,0]!=mask_value)*1.
    return x,y,sample_weights

tte_mean_train = np.nanmean(y_train[:,:,0])
mask_value = -1.3371337 
mean_u = np.nanmean(y_train[:,:,1])

x_test,y_test,sample_weights_test    = nanmask_to_keras_mask(x_test,y_test,mask_value,tte_mean_train)
x_train,y_train,sample_weights_train = nanmask_to_keras_mask(x_train,y_train,mask_value,tte_mean_train)

# Initialization value for alpha-bias 
init_alpha = -1.0/np.log(1.0-1.0/(tte_mean_train+1.0) )
init_alpha = init_alpha/mean_u
print('init_alpha: ',init_alpha,'mean uncensored train: ',mean_u)
# Out:
# init_alpha:  133.217260602 mean uncensored train:  1.0

# %%
import keras.backend as K
from keras.models import Sequential

from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import GRU
from keras.layers import Masking
from keras.layers import Lambda
from keras.layers import BatchNormalization
from keras.layers import Dropout

from keras.layers.wrappers import TimeDistributed

from keras.optimizers import RMSprop,adam
from keras import callbacks

import wtte.weibull as weibull
import wtte.wtte as wtte
from wtte.wtte import WeightWatcher

reduce_lr = callbacks.ReduceLROnPlateau(monitor='loss', 
                                        factor  =0.5, 
                                        patience=50, 
                                        verbose=0, 
                                        mode='auto', 
                                        epsilon=0.0001, 
                                        cooldown=0, 
                                        min_lr=1e-8)

nanterminator = callbacks.TerminateOnNaN()
history = callbacks.History()
weightwatcher = WeightWatcher(per_batch =False,per_epoch= True)

### MODEL PARAMETERS
n_features = x_train.shape[-1]
n_layers = 10
# Look into batchnorm
# https://stackoverflow.com/questions/40119736/keras-batchnorm-has-awful-test-performance
activation_list = ['relu','tanh','sigmoid']
activation = activation_list[1]
dropout_rate = 0.5
# Rescale initial alpha (seems to increase rapidly)
init_alpha = init_alpha

def base_model():
    model = Sequential()
    model.add(Masking(mask_value=mask_value,input_shape=(None, n_features)))
    for i in range(n_layers):
        model.add(BatchNormalization())
        model.add(GRU(3,activation=activation,return_sequences=True))
        #model.add(Dropout(dropout_rate)) 
    return model

def wtte_rnn():
    model = base_model()

    model.add(TimeDistributed(Dense(2)))
    model.add(Lambda(wtte.output_lambda, 
                     arguments={"init_alpha":init_alpha, 
                                "max_beta_value":4.0,
                                "alpha_kernel_scalefactor":1.0}))

    loss = wtte.loss(kind='discrete',reduce_loss=False).loss_function
    model.compile(loss=loss, optimizer=adam(lr=.01,clipvalue=0.5),sample_weight_mode='temporal')
    return model

# %%
### FITTING PARAMETERS

batch_size=50
max_epochs = 150 #100


model = wtte_rnn()
model.summary()

K.set_value(model.optimizer.lr, 0.01)
model.fit(x_train, y_train,
          epochs=max_epochs,
          batch_size=batch_size, 
          verbose=1,
          validation_data=(x_test, y_test,sample_weights_test),
          sample_weight = sample_weights_train,
          callbacks=[nanterminator,history,weightwatcher,reduce_lr])

plt.plot(history.history['loss'],    label='training')
plt.plot(history.history['val_loss'],label='validation')
plt.legend()
plt.show()
weightwatcher.plot()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# masking_14 (Masking)         (None, None, 30)          0
# _________________________________________________________________
# batch_normalization_39 (Batc (None, None, 30)          120
# _________________________________________________________________
# gru_45 (GRU)                 (None, None, 3)           306
# _________________________________________________________________
# batch_normalization_40 (Batc (None, None, 3)           12
# _________________________________________________________________
# gru_46 (GRU)                 (None, None, 3)           63
# _________________________________________________________________
# batch_normalization_41 (Batc (None, None, 3)           12
# _________________________________________________________________
# gru_47 (GRU)                 (None, None, 3)           63
# _________________________________________________________________
# batch_normalization_42 (Batc (None, None, 3)           12
# _________________________________________________________________
# gru_48 (GRU)                 (None, None, 3)           63
# _________________________________________________________________
# batch_normalization_43 (Batc (None, None, 3)           12
# _________________________________________________________________
# gru_49 (GRU)                 (None, None, 3)           63
# _________________________________________________________________
# batch_normalization_44 (Batc (None, None, 3)           12
# _________________________________________________________________
# gru_50 (GRU)                 (None, None, 3)           63
# _________________________________________________________________
# batch_normalization_45 (Batc (None, None, 3)           12
# _________________________________________________________________
# gru_51 (GRU)                 (None, None, 3)           63
# _________________________________________________________________
# batch_normalization_46 (Batc (None, None, 3)           12
# _________________________________________________________________
# gru_52 (GRU)                 (None, None, 3)           63
# _________________________________________________________________
# batch_normalization_47 (Batc (None, None, 3)           12
# _________________________________________________________________
# gru_53 (GRU)                 (None, None, 3)           63
# _________________________________________________________________
# batch_normalization_48 (Batc (None, None, 3)           12
# _________________________________________________________________
# gru_54 (GRU)                 (None, None, 3)           63
# _________________________________________________________________
# time_distributed_14 (TimeDis (None, None, 2)           8
# _________________________________________________________________
# lambda_14 (Lambda)           (None, None, 2)           0
# =================================================================
# Total params: 1,109
# Trainable params: 995
# Non-trainable params: 114
# _________________________________________________________________
# Train on 200 samples, validate on 49 samples
# Epoch 1/150
# 200/200 [==============================] - 22s 110ms/step - loss: 6.0946 - val_loss: 5.8579
# Epoch 2/150
# 200/200 [==============================] - 29s 144ms/step - loss: 5.9231 - val_loss: 5.8254
# Epoch 3/150
# 200/200 [==============================] - 25s 126ms/step - loss: 5.7770 - val_loss: 5.8368
# Epoch 4/150
# 200/200 [==============================] - 21s 104ms/step - loss: 5.7350 - val_loss: 5.8332
# Epoch 5/150
# 200/200 [==============================] - 16s 80ms/step - loss: 5.7110 - val_loss: 5.9711
# Epoch 6/150
# 200/200 [==============================] - 15s 76ms/step - loss: 5.6665 - val_loss: 6.0420
# Epoch 7/150
# 200/200 [==============================] - 17s 83ms/step - loss: 5.6314 - val_loss: 6.1489
# Epoch 8/150
# 200/200 [==============================] - 16s 78ms/step - loss: 5.6079 - val_loss: 6.2810
# Epoch 9/150
# 200/200 [==============================] - 15s 77ms/step - loss: 5.6016 - val_loss: 6.3055
# Epoch 10/150
# 200/200 [==============================] - 16s 81ms/step - loss: 5.5827 - val_loss: 6.3427
# Epoch 11/150
# 200/200 [==============================] - 16s 82ms/step - loss: 5.5695 - val_loss: 6.3909
# Epoch 12/150
# 200/200 [==============================] - 15s 73ms/step - loss: 5.5550 - val_loss: 6.3651
# Epoch 13/150
# 200/200 [==============================] - 15s 75ms/step - loss: 5.5521 - val_loss: 6.3391
# Epoch 14/150
# 200/200 [==============================] - 16s 79ms/step - loss: 5.5455 - val_loss: 6.2974
# Epoch 15/150
# 200/200 [==============================] - 15s 73ms/step - loss: 5.5361 - val_loss: 6.3118
# Epoch 16/150
# 200/200 [==============================] - 15s 73ms/step - loss: 5.5344 - val_loss: 6.2649
# Epoch 17/150
# 200/200 [==============================] - 15s 73ms/step - loss: 5.5282 - val_loss: 6.3375
# Epoch 18/150
# 200/200 [==============================] - 15s 73ms/step - loss: 5.5208 - val_loss: 6.3817
# Epoch 19/150
# 200/200 [==============================] - 15s 75ms/step - loss: 5.5187 - val_loss: 6.4182
# Epoch 20/150
# 200/200 [==============================] - 15s 73ms/step - loss: 5.5108 - val_loss: 6.4355
# Epoch 21/150
# 200/200 [==============================] - 15s 75ms/step - loss: 5.5073 - val_loss: 6.4970
# Epoch 22/150
# 200/200 [==============================] - 15s 73ms/step - loss: 5.4833 - val_loss: 6.5107
# Epoch 23/150
# 200/200 [==============================] - 15s 73ms/step - loss: 5.4604 - val_loss: 6.6334
# Epoch 24/150
# 200/200 [==============================] - 15s 73ms/step - loss: 5.4379 - val_loss: 6.7497
# Epoch 25/150
# 200/200 [==============================] - 15s 74ms/step - loss: 5.4124 - val_loss: 6.8534
# Epoch 26/150
# 200/200 [==============================] - 15s 74ms/step - loss: 5.4034 - val_loss: 7.2229
# Epoch 27/150
# 200/200 [==============================] - 15s 73ms/step - loss: 5.3660 - val_loss: 7.6605
# Epoch 28/150
# 200/200 [==============================] - 15s 73ms/step - loss: 5.3471 - val_loss: 7.8721
# Epoch 29/150
# 200/200 [==============================] - 15s 74ms/step - loss: 5.3546 - val_loss: 7.7962
# Epoch 30/150
# 200/200 [==============================] - 15s 75ms/step - loss: 5.3246 - val_loss: 8.2000
# Epoch 31/150
# 200/200 [==============================] - 16s 79ms/step - loss: 5.3578 - val_loss: 7.1121
# Epoch 32/150
# 200/200 [==============================] - 15s 74ms/step - loss: 5.2998 - val_loss: 6.1534
# Epoch 33/150
# 200/200 [==============================] - 15s 74ms/step - loss: 5.2908 - val_loss: 7.0328
# Epoch 34/150
# 200/200 [==============================] - 15s 73ms/step - loss: 5.3042 - val_loss: 6.8757
# Epoch 35/150
# 200/200 [==============================] - 15s 74ms/step - loss: 5.2944 - val_loss: 7.8317
# Epoch 36/150
# 200/200 [==============================] - 16s 80ms/step - loss: 5.3096 - val_loss: 7.3834
# Epoch 37/150
# 200/200 [==============================] - 17s 86ms/step - loss: 5.3014 - val_loss: 7.0553
# Epoch 38/150
# 200/200 [==============================] - 17s 84ms/step - loss: 5.2894 - val_loss: 7.8900
# Epoch 39/150
# 200/200 [==============================] - 18s 90ms/step - loss: 5.3049 - val_loss: 6.2480
# Epoch 40/150
# 200/200 [==============================] - 16s 81ms/step - loss: 5.2723 - val_loss: 6.7783
# Epoch 41/150
# 200/200 [==============================] - 15s 77ms/step - loss: 5.2780 - val_loss: 6.0039
# Epoch 42/150
# 200/200 [==============================] - 15s 74ms/step - loss: 5.2703 - val_loss: 5.8572
# Epoch 43/150
# 200/200 [==============================] - 15s 73ms/step - loss: 5.2601 - val_loss: 5.8771
# Epoch 44/150
# 200/200 [==============================] - 15s 73ms/step - loss: 5.2502 - val_loss: 6.5593
# Epoch 45/150
# 200/200 [==============================] - 15s 73ms/step - loss: 5.2948 - val_loss: 8.8937
# Epoch 46/150
# 200/200 [==============================] - 18s 92ms/step - loss: 5.3380 - val_loss: 6.9780
# Epoch 47/150
# 200/200 [==============================] - 18s 92ms/step - loss: 5.2505 - val_loss: 9.4101
# Epoch 48/150
# 200/200 [==============================] - 18s 89ms/step - loss: 5.2905 - val_loss: 9.4839
# Epoch 49/150
# 200/200 [==============================] - 17s 83ms/step - loss: 5.2521 - val_loss: 9.5323
# Epoch 50/150
# 200/200 [==============================] - 15s 73ms/step - loss: 5.2372 - val_loss: 10.0590
# Epoch 51/150
# 200/200 [==============================] - 15s 75ms/step - loss: 5.2495 - val_loss: 10.4388
# Epoch 52/150
# 200/200 [==============================] - 21s 106ms/step - loss: 5.2785 - val_loss: 10.3907
# Epoch 53/150
# 200/200 [==============================] - 19s 95ms/step - loss: 5.2596 - val_loss: 10.6845
# Epoch 54/150
# 200/200 [==============================] - 21s 104ms/step - loss: 5.2211 - val_loss: 11.2255
# Epoch 55/150
# 200/200 [==============================] - 18s 88ms/step - loss: 5.2630 - val_loss: 11.8647
# Epoch 56/150
# 200/200 [==============================] - 19s 97ms/step - loss: 5.2507 - val_loss: 10.6502
# Epoch 57/150
# 200/200 [==============================] - 20s 101ms/step - loss: 5.2714 - val_loss: 10.9274
# Epoch 58/150
# 200/200 [==============================] - 18s 89ms/step - loss: 5.2768 - val_loss: 11.3633
# Epoch 59/150
# 200/200 [==============================] - 17s 86ms/step - loss: 5.2838 - val_loss: 10.6743
# Epoch 60/150
# 200/200 [==============================] - 15s 76ms/step - loss: 5.2526 - val_loss: 10.5235
# Epoch 61/150
# 200/200 [==============================] - 15s 77ms/step - loss: 5.2271 - val_loss: 10.6564
# Epoch 62/150
# 200/200 [==============================] - 15s 73ms/step - loss: 5.2128 - val_loss: 11.1945
# Epoch 63/150
# 200/200 [==============================] - 15s 74ms/step - loss: 5.2300 - val_loss: 11.5494
# Epoch 64/150
# 200/200 [==============================] - 15s 73ms/step - loss: 5.1998 - val_loss: 11.9779
# Epoch 65/150
# 200/200 [==============================] - 15s 74ms/step - loss: 5.2028 - val_loss: 9.5463
# Epoch 66/150
# 200/200 [==============================] - 15s 74ms/step - loss: 5.2385 - val_loss: 12.2044
# Epoch 67/150
# 200/200 [==============================] - 15s 74ms/step - loss: 5.2717 - val_loss: 11.6816
# Epoch 68/150
# 200/200 [==============================] - 15s 73ms/step - loss: 5.2443 - val_loss: 10.7653
# Epoch 69/150
# 200/200 [==============================] - 15s 74ms/step - loss: 5.2775 - val_loss: 10.4599
# Epoch 70/150
# 200/200 [==============================] - 15s 73ms/step - loss: 5.2023 - val_loss: 10.7123
# Epoch 71/150
# 200/200 [==============================] - 15s 74ms/step - loss: 5.2260 - val_loss: 8.5627
# Epoch 72/150
# 200/200 [==============================] - 17s 85ms/step - loss: 5.2367 - val_loss: 10.8240
# Epoch 73/150
# 200/200 [==============================] - 30s 148ms/step - loss: 5.2597 - val_loss: 10.7394
# Epoch 74/150
# 200/200 [==============================] - 25s 127ms/step - loss: 5.2619 - val_loss: 10.5768
# Epoch 75/150
# 200/200 [==============================] - 19s 93ms/step - loss: 5.2375 - val_loss: 10.5803
# Epoch 76/150
# 200/200 [==============================] - 18s 91ms/step - loss: 5.2493 - val_loss: 10.7422
# Epoch 77/150
# 200/200 [==============================] - 18s 91ms/step - loss: 5.2154 - val_loss: 10.5427
# Epoch 78/150
# 200/200 [==============================] - 17s 87ms/step - loss: 5.2298 - val_loss: 11.0479
# Epoch 79/150
# 200/200 [==============================] - 18s 91ms/step - loss: 5.2083 - val_loss: 5.5358
# Epoch 80/150
# 200/200 [==============================] - 18s 89ms/step - loss: 5.1966 - val_loss: 5.5409
# Epoch 81/150
# 200/200 [==============================] - 18s 89ms/step - loss: 5.1773 - val_loss: 6.1452
# Epoch 82/150
# 200/200 [==============================] - 18s 89ms/step - loss: 5.2141 - val_loss: 5.8636
# Epoch 83/150
# 200/200 [==============================] - 18s 88ms/step - loss: 5.2275 - val_loss: 5.5971
# Epoch 84/150
# 200/200 [==============================] - 19s 95ms/step - loss: 5.2479 - val_loss: 5.6989
# Epoch 85/150
# 200/200 [==============================] - 18s 89ms/step - loss: 5.2818 - val_loss: 5.4910
# Epoch 86/150
# 200/200 [==============================] - 18s 90ms/step - loss: 5.2356 - val_loss: 6.0988
# Epoch 87/150
# 200/200 [==============================] - 20s 100ms/step - loss: 5.2181 - val_loss: 5.6516
# Epoch 88/150
# 200/200 [==============================] - 26s 129ms/step - loss: 5.1957 - val_loss: 7.1448
# Epoch 89/150
# 200/200 [==============================] - 25s 127ms/step - loss: 5.1803 - val_loss: 6.7282
# Epoch 90/150
# 200/200 [==============================] - 31s 155ms/step - loss: 5.2064 - val_loss: 6.4857
# Epoch 91/150
# 200/200 [==============================] - 27s 135ms/step - loss: 5.2050 - val_loss: 6.2556
# Epoch 92/150
# 200/200 [==============================] - 25s 125ms/step - loss: 5.1935 - val_loss: 7.9668
# Epoch 93/150
# 200/200 [==============================] - 31s 157ms/step - loss: 5.2038 - val_loss: 5.1883
# Epoch 94/150
# 200/200 [==============================] - 21s 105ms/step - loss: 5.2152 - val_loss: 8.5202
# Epoch 95/150
# 200/200 [==============================] - 25s 126ms/step - loss: 5.2199 - val_loss: 10.6036
# Epoch 96/150
# 200/200 [==============================] - 18s 92ms/step - loss: 5.2228 - val_loss: 10.6669
# Epoch 97/150
# 200/200 [==============================] - 18s 91ms/step - loss: 5.2196 - val_loss: 10.5122
# Epoch 98/150
# 200/200 [==============================] - 18s 92ms/step - loss: 5.2162 - val_loss: 7.8497
# Epoch 99/150
# 200/200 [==============================] - 17s 87ms/step - loss: 5.2075 - val_loss: 5.4120
# Epoch 100/150
# 200/200 [==============================] - 17s 83ms/step - loss: 5.1954 - val_loss: 6.4759
# Epoch 101/150
# 200/200 [==============================] - 17s 84ms/step - loss: 5.1926 - val_loss: 5.8661
# Epoch 102/150
# 200/200 [==============================] - 17s 83ms/step - loss: 5.1719 - val_loss: 6.1784
# Epoch 103/150
# 200/200 [==============================] - 17s 84ms/step - loss: 5.1715 - val_loss: 7.6484
# Epoch 104/150
# 200/200 [==============================] - 17s 83ms/step - loss: 5.1677 - val_loss: 9.8129
# Epoch 105/150
# 200/200 [==============================] - 16s 82ms/step - loss: 5.1583 - val_loss: 10.7188
# Epoch 106/150
# 200/200 [==============================] - 17s 85ms/step - loss: 5.1648 - val_loss: 10.7698
# Epoch 107/150
# 200/200 [==============================] - 17s 86ms/step - loss: 5.1576 - val_loss: 11.5558
# Epoch 108/150
# 200/200 [==============================] - 16s 81ms/step - loss: 5.1390 - val_loss: 8.2622
# Epoch 109/150
# 200/200 [==============================] - 16s 82ms/step - loss: 5.1701 - val_loss: 6.6299
# Epoch 110/150
# 200/200 [==============================] - 17s 84ms/step - loss: 5.1702 - val_loss: 5.2549
# Epoch 111/150
# 200/200 [==============================] - 20s 100ms/step - loss: 5.1672 - val_loss: 11.4100
# Epoch 112/150
# 200/200 [==============================] - 19s 96ms/step - loss: 5.1457 - val_loss: 10.4374
# Epoch 113/150
# 200/200 [==============================] - 18s 89ms/step - loss: 5.1607 - val_loss: 10.8072
# Epoch 114/150
# 200/200 [==============================] - 18s 89ms/step - loss: 5.1564 - val_loss: 10.6110
# Epoch 115/150
# 200/200 [==============================] - 16s 81ms/step - loss: 5.1239 - val_loss: 11.1100
# Epoch 116/150
# 200/200 [==============================] - 17s 87ms/step - loss: 5.1200 - val_loss: 11.3972
# Epoch 117/150
# 200/200 [==============================] - 20s 100ms/step - loss: 5.1271 - val_loss: 5.9900
# Epoch 118/150
# 200/200 [==============================] - 25s 125ms/step - loss: 5.0870 - val_loss: 5.1542
# Epoch 119/150
# 200/200 [==============================] - 36s 181ms/step - loss: 5.1273 - val_loss: 10.9875
# Epoch 120/150
# 200/200 [==============================] - 26s 132ms/step - loss: 5.1456 - val_loss: 11.0829
# Epoch 121/150
# 200/200 [==============================] - 29s 147ms/step - loss: 5.1428 - val_loss: 10.8493
# Epoch 122/150
# 200/200 [==============================] - 28s 140ms/step - loss: 5.1236 - val_loss: 10.8720
# Epoch 123/150
# 200/200 [==============================] - 29s 144ms/step - loss: 5.1260 - val_loss: 10.8000
# Epoch 124/150
# 200/200 [==============================] - 32s 160ms/step - loss: 5.1120 - val_loss: 11.8639
# Epoch 125/150
# 200/200 [==============================] - 34s 172ms/step - loss: 5.0912 - val_loss: 11.0823
# Epoch 126/150
# 200/200 [==============================] - 41s 204ms/step - loss: 5.1155 - val_loss: 11.7724
# Epoch 127/150
# 200/200 [==============================] - 39s 195ms/step - loss: 5.1014 - val_loss: 9.5272
# Epoch 128/150
# 200/200 [==============================] - 37s 187ms/step - loss: 5.0941 - val_loss: 10.4905
# Epoch 129/150
# 200/200 [==============================] - 38s 188ms/step - loss: 5.0784 - val_loss: 10.8625
# Epoch 130/150
# 200/200 [==============================] - 38s 189ms/step - loss: 5.0714 - val_loss: 11.7281
# Epoch 131/150
# 200/200 [==============================] - 39s 195ms/step - loss: 5.1153 - val_loss: 11.2564
# Epoch 132/150
# 200/200 [==============================] - 39s 196ms/step - loss: 5.1374 - val_loss: 11.3808
# Epoch 133/150
# 200/200 [==============================] - 37s 184ms/step - loss: 5.1591 - val_loss: 7.2571
# Epoch 134/150
# 200/200 [==============================] - 38s 188ms/step - loss: 5.0963 - val_loss: 10.0572
# Epoch 135/150
# 200/200 [==============================] - 37s 186ms/step - loss: 5.1045 - val_loss: 10.1345
# Epoch 136/150
# 200/200 [==============================] - 35s 177ms/step - loss: 5.1094 - val_loss: 10.1793
# Epoch 137/150
# 200/200 [==============================] - 37s 184ms/step - loss: 5.0624 - val_loss: 10.1206
# Epoch 138/150
# 200/200 [==============================] - 37s 183ms/step - loss: 5.1096 - val_loss: 6.5806
# Epoch 139/150
# 200/200 [==============================] - 36s 180ms/step - loss: 5.1163 - val_loss: inf
# Epoch 140/150
# 200/200 [==============================] - 37s 184ms/step - loss: 5.1119 - val_loss: 6.2716
# Epoch 141/150
# 200/200 [==============================] - 37s 187ms/step - loss: 5.1463 - val_loss: 10.6536
# Epoch 142/150
# 200/200 [==============================] - 38s 189ms/step - loss: 5.1859 - val_loss: 7.2235
# Epoch 143/150
# 200/200 [==============================] - 36s 179ms/step - loss: 5.1224 - val_loss: 5.1532
# Epoch 144/150
# 200/200 [==============================] - 35s 175ms/step - loss: 5.1053 - val_loss: 5.2947
# Epoch 145/150
# 200/200 [==============================] - 38s 188ms/step - loss: 5.1012 - val_loss: 8.6082
# Epoch 146/150
# 200/200 [==============================] - 31s 157ms/step - loss: 5.1176 - val_loss: 9.3405
# Epoch 147/150
# 200/200 [==============================] - 34s 172ms/step - loss: 5.1109 - val_loss: 10.3800
# Epoch 148/150
# 200/200 [==============================] - 29s 143ms/step - loss: 5.1323 - val_loss: 5.4423
# Epoch 149/150
# 200/200 [==============================] - 29s 147ms/step - loss: 5.2223 - val_loss: 6.5316
# Epoch 150/150
# 200/200 [==============================] - 29s 145ms/step - loss: 5.2329 - val_loss: 9.7099

# %%
# Optional: add a margin of zeros at the end of the sequence to see what the 
# model does after the first events (if it identifies death by pushing prediction to inf)

mask = np.copy(x_test)
mask[mask==mask_value] = np.nan
mask = mask*0
predicted = model.predict(x_test)+mask[:,:,:1]

alpha_flat = predicted[:,:,0][~np.isnan(predicted[:,:,0])].flatten()
beta_flat  = predicted[:,:,1][~np.isnan(predicted[:,:,0])].flatten()

## log-alpha typically makes more sense.
from matplotlib.colors import LogNorm
counts, xedges, yedges, _ = plt.hist2d(alpha_flat, beta_flat, bins=50,norm=LogNorm())
plt.title('Predicted params : density')
plt.xlim([alpha_flat.min(),alpha_flat.max()])
plt.ylim([beta_flat.min(),beta_flat.max()])
plt.xlabel(r'$\alpha$')
plt.ylabel(r'$\beta$')
plt.show()

# Pick out prediction for one sequence
batch_indx = 500
print('Bad Example?:')
for batch_indx in [5,20]:
    seq_len = (~np.isnan(predicted[batch_indx,:,0])).sum()
    a = predicted[batch_indx,:seq_len,0]+mask[batch_indx,:seq_len,0]
    b = predicted[batch_indx,:seq_len,1]+mask[batch_indx,:seq_len,0]
    t = np.array(xrange(len(a)))+mask[batch_indx,:seq_len,0]

    tte_actual   = y_test[batch_indx,:seq_len,0]+mask[batch_indx,:seq_len,0]

    ##### Prediction (Using weibull-quantities like quantiles etc)
    drawstyle = 'steps-post'
    plt.plot(t,tte_actual,label='uncensored tte',color='black',linestyle='solid',linewidth=2,drawstyle=drawstyle)

    plt.plot(weibull.quantiles(a,b,0.75),color='blue',label='pred <0.75',drawstyle=drawstyle)
    plt.plot(weibull.mode(a, b), color='red',linewidth=1,label='pred mode/peak prob',drawstyle=drawstyle)
    plt.plot(weibull.mean(a, b), color='green',linewidth=1,label='pred mean',drawstyle='steps-post')
    plt.plot(weibull.quantiles(a,b,0.25),color='blue',label='pred <0.25',drawstyle=drawstyle)

    #     plt.ylim(0, 2*np.nanmax(tte_actual))
    plt.xlabel('time')
    plt.ylabel('time to event')
    plt.title('prediction sequence '+str(batch_indx),)
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    plt.show()
    print('Good Example?:')

print('alpha : mean   ',alpha_flat.mean())
print('alpha : median ',np.median(alpha_flat))
print('alpha :    min ',alpha_flat.min())
print('alpha :    max ',alpha_flat.max())
print('beta  : mean   ',beta_flat.mean())
print('beta  : median ',np.median(beta_flat))
print('beta  :    min ',beta_flat.min())
print('beta  :    max ',beta_flat.max())
# Out:
# Bad Example?:
# Good Example?:
# Good Example?:
# alpha : mean    34.3461833841
# alpha : median  22.513092041
# alpha :    min  10.9469575882
# alpha :    max  238.953018188
# beta  : mean    1.24548185522
# beta  : median  1.12517547607
# beta  :    min  0.68982809782
# beta  :    max  2.97753238678

# %%
### PRINT TRAINING EXAMPLE
mask = np.copy(x_train)
mask[mask==mask_value] = np.nan
mask = mask*0

predicted = model.predict(x_train)+mask[:,:,:1]


for batch_indx in [5,20]:
    seq_len = (~np.isnan(predicted[batch_indx,:,0])).sum()
    a = predicted[batch_indx,:seq_len,0]+mask[batch_indx,:seq_len,0]
    b = predicted[batch_indx,:seq_len,1]+mask[batch_indx,:seq_len,0]
    t = np.array(xrange(len(a)))+mask[batch_indx,:seq_len,0]

    tte_actual   = y_train[batch_indx,:seq_len,0]+mask[batch_indx,:seq_len,0]

    ##### Prediction (Using weibull-quantities like quantiles etc)
    drawstyle = 'steps-post'
    plt.plot(t,tte_actual,label='uncensored tte',color='black',linestyle='solid',linewidth=2,drawstyle=drawstyle)

    plt.plot(weibull.quantiles(a,b,0.75),color='blue',label='pred <0.75',drawstyle=drawstyle)
    plt.plot(weibull.mode(a, b), color='red',linewidth=1,label='pred mode/peak prob',drawstyle=drawstyle)
    plt.plot(weibull.mean(a, b), color='green',linewidth=1,label='pred mean',drawstyle='steps-post')
    plt.plot(weibull.quantiles(a,b,0.25),color='blue',label='pred <0.25',drawstyle=drawstyle)

    #     plt.ylim(0, 2*np.nanmax(tte_actual))
    plt.xlabel('time')
    plt.ylabel('time to event')
    plt.title('training sequence '+str(batch_indx),)
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    plt.show()
